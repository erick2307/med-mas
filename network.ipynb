# %%
import networkx as nx
import pandas as pd
import numpy as np

#create a graph
G = nx.Graph()
#read data
Nodesdf = pd.read_csv('/Volumes/GoogleDrive/My\Drive/Colab\Notebooks/nodes.csv',names=["y","x","id","hw","v_FID"],skiprows=1)
Edgesdf = pd.read_csv('/Volumes/GoogleDrive/My\Drive/Colab\Notebooks/edges.csv',names=["id","name","hw","oneway","length","from","to","lanes","service","access","maxspeed","ref","width","junction","bridge","tunnel","u","v","key"],skiprows=1)
#Sheltersdf = Nodesdf[Nodesdf["type"] == 1]
# Out:
#   File "<ipython-input-4-39814c5cb036>", line 8
#     Nodesdf = pd.read_csv('/Volumes/GoogleDrive/My\Drive/Colab\Notebooks/nodes.csv',names=["y","x","id","hw","v_FID"],skiprows=1)
#                          ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 35-36: malformed \N character escape
